# %%
# %matplotlib inline
import googlemaps
import pandas as pd
import simplejson as sj
import urllib as urllib
import os
import ast
import numpy as np
import matplotlib.pyplot as plt

carreteras_df = pd.read_csv('Carreteras.csv', encoding='UTF-8', delimiter=',')

gmaps = googlemaps.Client(key='AIzaSyAh2PIcLDrPecSSR36z2UNubqphdHwIw7M')

# %%
carreteras_coord = carreteras_df.st_Y.astype(str).str.cat(carreteras_df.st_X.astype(str), sep=',')
carreteras_coord = carreteras_coord.values.tolist()

# %%
    f = open('carreteras_distance.dat', 'w')
    f.write(str(distance_table))
    f.close()

# %%
    f = open('carreteras_elevation.dat', 'w')
    f.write(str(elevationArray))
    f.close()

# %%
distance_table =[]
distance_table.append(0)

# %%
distance_table.append(distance_table[0]+1)

# %%
f = open('carreteras_elevation.dat', 'r')
carreteras_elevation = f.read()
f.close()
carreteras_elevation = ast.literal_eval(carreteras_elevation)
f = open('carreteras_distance.dat', 'r')
carreteras_distance = f.read()
f.close()
carreteras_distance = ast.literal_eval(carreteras_distance)

# %%
pd.set_option('display.mpl_style', 'default')
plt.rcParams['figure.figsize'] = (15, 3)
plt.rcParams['font.family'] = 'sans-serif'
plt.plot(range(0,len(carreteras_elevation)),carreteras_elevation)
plt.xticks(carreteras_distance)
plt.show()

# %%
distance_large = range(1,len(carreteras_elevation))
