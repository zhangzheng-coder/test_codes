# %% [raw]
# <script>
#   jQuery(document).ready(function($) {
#
#   $(window).load(function(){
#     $('#preloader').fadeOut('slow',function(){$(this).remove();});
#   });
#
#   });
# </script>
#
# <style type="text/css">
#   div#preloader { position: fixed;
#       left: 0;
#       top: 0;
#       z-index: 999;
#       width: 100%;
#       height: 100%;
#       overflow: visible;
#       background: #fff url('http://preloaders.net/preloaders/720/Moving%20line.gif') no-repeat center center;
#   }
#
# </style>
#
# <div id="preloader">
#
# </div>

# %% [raw]
# <script>
#   function code_toggle() {
#     if (code_shown){
#       $('div.input').hide('500');
#       $('#toggleButton').val('Show Code')
#     } else {
#       $('div.input').show('500');
#       $('#toggleButton').val('Hide Code')
#     }
#     code_shown = !code_shown
#   }
#
#   $( document ).ready(function(){
#     code_shown=false;
#     $('div.input').hide()
#   });
# </script>
# <form action="javascript:code_toggle()"><input type="submit" id="toggleButton" value="Show Code"></form>

# %%
# %matplotlib inline
# Importing the relevant packages including division from the future package so the code is 
# Python 3.xx compatible
from __future__ import division
import pandas as pd
import random as rnd
from scipy import stats
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter, MaxNLocator
#Use the same random seed to make results replicable
rnd.seed(1235822231)

# %% [markdown]
# # About The Paper
# ### Reviewers: Lara, J. D., Lobos, A.A. Lokhandwala, N. Y.
#
# Disclaimer "This review was vetted by Philip B. Stark. However, the work was conducted entirely by the authors, and the opinions expressed in this review are those of the authors."
#
# The [paper](https://www.scienceopen.com/document/review?3&id=7a235c56-a1da-498f-98ef-6fa16c8fd2f0&review=9870bf08-c06e-403a-85ba-774e27cdb520) presents an analysis of data from radiobiological experiments carried out in a laboratory. Out of the data, there is the suspicion that some of the results may be biased or fabricated. The authors used long term data produced in the same laboratory along with data from other sources that use the same techniques as benchmark data, and make comparisons with the suspected data.
#
# The techniques used looked into two possible sources of suspicion, first the ratio of the distances between triplicate samples assuming that a way to fabricate the data is to pre-select an average, and then fixing the other to samples to achieve the desired average. The authors checked how likely it is that the average value of the sample is present in the triplicate values using a Poisson - binomial distribution test. The authors use the highest value of the probability (0.42) that a Poisson generated triplicate contains it's mean for the first hypothesis test. The use of this probability value is a good practice since it provides an upper bound on the p-value that is a very conservative estimate, which is desirable since the nature of the study is quite sensitive.
#
# Furthermore, the Poisson model for the triplets is appropriate, as there are a large number of cells in each colony, $n \rightarrow \infty$ and each cell has the same probability of survival as it has been exposed to the same amount of radiation. Hence, we believe the choice to use a Poisson distribution to approximate the binomial is justified. Also, the authors draw some statistical analysis of the likelihood that the mid ratios are close to or exactly 0.5; however, we believe that a more thorough analysis of this observation is required.
#
# Finally, the authors analyze the rightmost digit in search for possible fabrication, using a standard analysis. Even though this is an interesting metric, considering that the technique by [Mosimann](http://www.tandfonline.com/doi/abs/10.1080/08989620212969) has been widely used and studied we prefered to focus on the distance ratio indicator and perform complementary tests. At the end of the paper the authors carried out a  $\chi^2$ permutation test assess the goodness of fit of the terminal digits, a test motivation is not clear in the paper.
#
# TA notable difficulty in the paper, also acknowledged by the authors, is that the sample size of the suspected data is significantly larger than the benchmark data. Hence, the total population data is dominated by the suspected data. Moreover, the data provided was already categorized between the suspicious and the benchmark, thus biasing the direction of the test towards "proving that a set of data might be biased" instead of a more transparent analysis of finding suspicious data in a pool. In other words, it presupposes that the data from the it presupposes that the RTS data are special. From this point of view, the tests were not "blind." The strength of the evidence depends in part on whether the same data that led the researchers to suspect the RTS were the data used to test the hypothesis that the data collected by the RTS were different from the rest.
#
# Nevertheless, we believe the authors made an interesting contribution by providing the scientific community with methods to potentially test for data fabrication in radiobiological data. As a review good practice, we carried out some analysis of the submitted data to check for possible unintended errors in the data processing. Also, calculation of the ratios in two ways, testing the upper value of the ratios and also the lower value. In order to also test the assumption of uniformity of the ratios, we simulated data triplets drawn from a Poission distribtuion with the same means as those reported in the dataset.
#
# In the following sections of the review, we analyze the data quality and whether the samples sizes are actually as reported, corroborated the assumption that the ratios of the benchmark data indeed may follow a uniform distribution and included an alternative anaysis of the suspected data using [Kolmogorov-Smirnov test](https://en.wikipedia.org/wiki/Kolmogorov–Smirnov_test) comparing against an uniform distribution. The synthetic Poisson data was also evaluated using the [Kolmogorov-Smirnov test](https://en.wikipedia.org/wiki/Kolmogorov–Smirnov_test).
#
# Moreover, as an alternative measure, we used a 2-Sample [Kolmogorov-Smirnov test](https://en.wikipedia.org/wiki/Kolmogorov–Smirnov_test) to test whether the suspected data and the benchmark data could have come from the same population without making any assumptions about the underlying probability distribution.

# %% [markdown]
# # Data Loading And Count Check.
# This portion of the code is intended to load the datafiles into dataframes to enable the planned tests and calculations. Also we will present the verification of the results from Table 2 presented in the [paper](https://www.scienceopen.com/document/review?3&id=7a235c56-a1da-498f-98ef-6fa16c8fd2f0&review=9870bf08-c06e-403a-85ba-774e27cdb520).
#
# In the following lines of code we have dropped the columns not relevant for the analysis, renamed and re-arranged the columns of the various data-frames to have the same format across all the data frames. The final outcome are dataframes for each data source and a merged dataframe with all the samples.

# %%
#Reading in the raw data
#Dropping unecessary columns
#Renaming columns to be standard across all the Dataframes
#Re-arranging the collumn order so it is standard across all data frames 

#Colony dataframes
bishayee_colony = pd.read_excel("Bishayee Colony Counts 10.27.97-3.8.01.xlsx", skiprows=2,na_values=" ")
outside3_colony = pd.read_excel("Outside Lab 3.Colony Counts.2.4.10-5.21.12.xlsx", skiprows=1)
others_colony = pd.read_excel("Other Investigators in Lab.Colony Counts.4.23.92-11.27.02.xlsx", skiprows=1)

#Clean up of the colony data
bishayee_colony["Inv"] = "Z"
bishayee_colony.drop('ISOTOPE', axis=1, inplace=True)
bishayee_colony2 = bishayee_colony.iloc[:,[0,1,6,2,3,4,5]]
bishayee_colony2.columns
bishayee_colony2.rename(columns={'Bate # B0/B00':'Batch'},inplace = True)
bishayee_colony2.drop('Batch', axis=1, inplace=True)
bishayee_colony2.drop("Date",axis =1,inplace=True)
others_colony2 = others_colony.rename(columns={'Bates # B00 or B0':'Batch'})
others_colony2.drop('Batch', axis=1, inplace=True)
others_colony2.drop("Date",axis =1,inplace=True)
outside3_colony["Inv"] = "O"
outside3_colony2=outside3_colony.iloc[:,[0,5,1,2,3,4]]
outside3_colony2.rename(columns={'date':'Date','c1':'col1','c2':'col2','c3':'col3'},inplace = True)
outside3_colony2.drop("Date",axis =1,inplace=True)
df_total = [bishayee_colony2,others_colony2,outside3_colony2]

#Merging colony data into one data frame 
merged_colony_data = pd.concat(df_total)    

#Coulter dataframes
bishayee_coulter = pd.read_excel("Bishayee Coulter Counts.10.20.97-7.16.01.xlsx", skiprows=1)
others_coulter = pd.read_excel("Other Investigators in Lab.Coulter Counts.4.15.92-5.21.05.xlsx", skiprows=1)

#This data file had no header, introduced manually
outside1_coulter = pd.read_excel("Outside Lab 1.Coulter Counts.6.7.91-4.9.99.xlsx")
outside1_coulter.columns = ["Experiment", "C1", "C2", "C3","Average","Date"]
outside2_coulter = pd.read_excel("Outside Lab 2.Coulter Counts.6.6.08-7.7.08.xlsx", skiprows=1)

#Clean up of the coulter data 
bishayee_coulter2 = bishayee_coulter.drop('Bates', axis=1)
bishayee_coulter2["Inv"] = "Z"
bishayee_coulter2 = bishayee_coulter2.iloc[:,[0,5,1,2,3,4]]
bishayee_coulter2.rename(columns={'Count 1':'col1','Count 2':'col2','Count 3':'col3'},inplace=True)
bishayee_coulter2.drop("Date",axis =1,inplace=True)
outside1_coulter2 = outside1_coulter.drop('Experiment', axis = 1)
outside1_coulter2["Inv"] = "O1"
outside1_coulter2 = outside1_coulter2.iloc[:,[4,5,0,1,2,3]]
outside1_coulter2.rename(columns={'C1':'col1','C2':'col2','C3':'col3'},inplace=True)
outside1_coulter2.drop("Date",axis =1,inplace=True)
outside2_coulter2 = outside2_coulter.rename(columns={'Count 1':"col1",'Count 2':"col2",'Count 3':"col3"})
outside2_coulter2["Inv"] = "O2"
outside2_coulter2 = outside2_coulter2.iloc[:,[0,5,1,2,3,4]]
outside2_coulter2.drop("Date",axis =1,inplace=True)
others_coulter2 = others_coulter.drop('Bates No.', axis = 1)
others_coulter2.rename(columns={'Coul 1':'col1','Coul 2':'col2','Coul 3':'col3','Investigator':'Inv'},\
                       inplace=True)
others_coulter2 = others_coulter2.iloc[:,[0,5,1,2,3,4]]
others_coulter2.drop("Date",axis =1,inplace=True)
df_total_coulter = [bishayee_coulter2,others_coulter2,outside1_coulter2,outside2_coulter2]

#Merging coulter data into one data frame 
merged_coulter_data = pd.concat(df_total_coulter)

# %% [markdown]
# The following step is to verify the number of records of the data in the sets for the Coulter counts and the colony counts. From the description of the experimental set-up, it seems that the count of the cells using the Coulter and the colony count are actually individual experiments with different counting methods. The Coulter count is read off an LED display and the Colony count is observed through a microsocope.
# This is an important distinction to note, since manual counts are arguably more prone to human error and are easier to manipulate.

# %% [markdown]
# #### Completeness test of the combined colony data:

# %%
#Checking the data count in each data frame
print 'Total number of colony data triplets  ' + str(merged_colony_data.index.size)
print 'Total number of suspected colony data triplets  ' + str(bishayee_colony2.index.size)
print 'Total number of others colony data triplets  ' + str(others_colony2.index.size)
print 'Total number of outside lab 3 colony data triplets  ' + str(outside3_colony2.index.size)
# Out:
# Total number of colony data triplets  2033
# Total number of suspected colony data triplets  1362
# Total number of others colony data triplets  621
# Total number of outside lab 3 colony data triplets  50

# %% [markdown]
# The raw total number of samples doesn't coincide with the numbers in the [paper](https://www.scienceopen.com/document/review?3&id=7a235c56-a1da-498f-98ef-6fa16c8fd2f0&review=9870bf08-c06e-403a-85ba-774e27cdb520). Furthermore, the labeling of the outside labs is not consistent. It looks like the authors labeled the outside colony counts as lab1 when it is actually lab3.
#
# The following step is to eliminate incomplete triples and drop the na rows and check again against the authors' table. The designation (AD) is used to differentiate the data after drop. The total counts after the drop are as follows:

# %%
#Using regular expressions to search for blank cells with one or more spaces and 
#replcing those spaces with NaN
merged_colony_data.replace(r'\s*',np.nan, regex=True)

#Dropping incomplete triplets
merged_colony_data=merged_colony_data.dropna()

#Resetting the indices for the colony data frame, since pd.concat preserves the 
#indices of the orignal data frames
merged_colony_data.reset_index(drop=True)
print 'Total number of colony data triplets (AD) ' + str(merged_colony_data.index.size) 

#Follow the same procedure for the the other data frames to drop incomplete triplets
bishayee_colony2.replace(r'\s*',np.nan, regex=True)
bishayee_colony2 = bishayee_colony2.dropna()
bishayee_colony2.reset_index(drop=True)
print 'Total number of suspected colony data triplets (AD) ' + str(bishayee_colony2.index.size)
others_colony2.replace(r'\s*',np.nan, regex=True)
others_colony2 = others_colony2.dropna()
others_colony2.reset_index(drop=True)
print 'Total number of others colony data triplets (AD) ' + str(others_colony2.index.size)
outside3_colony2.replace(r'\s*',np.nan, regex=True)
outside3_colony2 = outside3_colony2.dropna()
outside3_colony2.reset_index(drop=True)
print 'Total number of outside lab 3 colony data triplets (AD) ' + str(outside3_colony2.index.size)
# Out:
# Total number of colony data triplets (AD) 2008
# Total number of suspected colony data triplets (AD) 1361
# Total number of others colony data triplets (AD) 597
# Total number of outside lab 3 colony data triplets (AD) 50

# %% [markdown]
# #### Completeness test for Coulter data:

# %% [markdown]
# The same data clean up and count of the the triplets is performed with the Coulter data, the resulting counts are as follows:

# %%
print 'Total number of Coulter data triplets  ' + str(merged_coulter_data.index.size)
print 'Total number of suspected Coulter data triplets  ' + str(bishayee_coulter2.index.size)
print 'Total number of others Coulter data triplets  ' + str(others_coulter2.index.size)
print 'Total number of outside lab1 data triplets  ' + str(outside1_coulter2.index.size)
print 'Total number of outside lab2 data triplets  ' + str(outside2_coulter2.index.size)
# Out:
# Total number of Coulter data triplets  2965
# Total number of suspected Coulter data triplets  1729
# Total number of others Coulter data triplets  1007
# Total number of outside lab1 data triplets  109
# Total number of outside lab2 data triplets  120

# %%
#Using regular expressions to search for blank cells with one or more spaces and replcing those spaces with NaN
merged_coulter_data.replace(r'\s*',np.nan, regex=True)

#Dropping incomplete triplets
merged_coulter_data = merged_coulter_data.dropna()

#Resetting the indices for the coulter data frame, since pd.concat preserves the indices of the orignal data frames
merged_coulter_data.reset_index(drop=True)
print 'Total number of Coulter data triplets (AD) ' + str(merged_coulter_data.index.size)

#Follow the same procedure for the the other data frames to drop incomplete triplets
bishayee_coulter2.replace(r'\s*',np.nan, regex=True)
bishayee_coulter2 = bishayee_coulter2.dropna()
bishayee_coulter2.reset_index(drop=True)
print 'Total number of suspected Coulter data triplets (AD) ' + str(bishayee_coulter2.index.size)
others_coulter2.replace(r'\s*',np.nan, regex=True)
others_coulter2 = others_coulter2.dropna()
others_coulter2.reset_index(drop=True)
print 'Total number of others Coulter data triplets (AD) ' + str(others_coulter2.index.size)
outside1_coulter2.replace(r'\s*',np.nan, regex=True)
outside1_coulter2 = outside1_coulter2.dropna()
outside1_coulter2.reset_index(drop=True)
print 'Total number of outside lab1 data triplets (AD) ' + str(outside1_coulter2.index.size)
outside2_coulter2.replace(r'\s*',np.nan, regex=True)
outside2_coulter2 = outside2_coulter2.dropna()
outside2_coulter2.reset_index(drop=True)
print 'Total number of outside lab2 data triplets (AD) ' + str(outside2_coulter2.index.size)
# Out:
# Total number of Coulter data triplets (AD) 2873
# Total number of suspected Coulter data triplets (AD) 1727
# Total number of others Coulter data triplets (AD) 929
# Total number of outside lab1 data triplets (AD) 97
# Total number of outside lab2 data triplets (AD) 120

# %% [markdown]
# The analysis of the complete triples yields a discrepancy when compared to Table 2. The results of the count are consistent for "total" in the fourth column. The RTS (suspected) colony counts, and the outside lab3 (labeled in the [paper](https://www.scienceopen.com/document/review?3&id=7a235c56-a1da-498f-98ef-6fa16c8fd2f0&review=9870bf08-c06e-403a-85ba-774e27cdb520) as lab1) are equal. The only discrepancy is the count for the other's colony count; however, the discrepancy is very small i.e., 8 triplets.
#
# In the case of the Coulter counts there is no discrepancy with respect to the No. complete, the others, lab2 and lab1 (labeled in the [paper](https://www.scienceopen.com/document/review?3&id=7a235c56-a1da-498f-98ef-6fa16c8fd2f0&review=9870bf08-c06e-403a-85ba-774e27cdb520) as lab3) are consistent with Table 2. The discrepancy appears in the RTS (suspected) sample, but again it is a comparatively small differnece i.e., 11.
#
# It is worth nothing that the authors dropped triplets with gap $\ge$ 2, this is not completely explained in the [paper](https://www.scienceopen.com/document/review?3&id=7a235c56-a1da-498f-98ef-6fa16c8fd2f0&review=9870bf08-c06e-403a-85ba-774e27cdb520) and it is only mentioned in a footnote in Table 2. If there are issues with the gaps, they are expected to show up in the ratio of the distances between the samples in the forthcoming analysis, and will be dealt with in the following section.

# %% [markdown]
# ## Calculation of the distance ratios
#
# A function is used to take a dataframe and add columns with the values of the distance ratios between the samples, even though the [paper](https://www.scienceopen.com/document/review?3&id=7a235c56-a1da-498f-98ef-6fa16c8fd2f0&review=9870bf08-c06e-403a-85ba-774e27cdb520) only mentions a single ratio we tested the distances from the mid value in both directions. The proceedure for the calculations is as follows:
#
# $$
# \begin{align}
# \text{sort} (\hat{t})\\
# \\
# LowerRatio = \frac{\hat{t}(2) - \hat{t}(1)}{\hat{t}(3) - \hat{t}(1)}\\
# \\
# UpperRatio = \frac{\hat{t}(3) - \hat{t}(2)}{\hat{t}(3) - \hat{t}(1)}
# \end{align}
# $$
#
# The final output of the function are two numpy vectors with the Upper Ratio (UR) and Lower Ratio (LR) values

# %% [markdown]
# If any ratio is NaN because all the numbers are the same then it gets dropped when calculating UR and LR. After this process the total amount of triplets gets counted again to review if the counts still match. The test is labeld as Valid Rarios counts (VR)

# %%
#Print empirical CDF plot from a data vector x. 
def cdf_plot(x):
    """ Print a CDF from a data vector"""
    x_data = np.sort(x)
    y_data = 1. * np.arange(len(x_data))/(len(x_data)-1)
    plt.plot(x_data, y_data)

# %%
def DistanceRatioCalculation(data_frame,startIndex=1):
    '''
    Calculates the ratio of the distance between a triplet sample.
    The startIndex is needed because in most of the dataFrame the columns 
    start in the first second column (column 1 here), but not in all cases.
    $$
    \begin{align}
    \text{sort} (\hat{t})\\
    \\
    LowerRatio = \frac{\hat{t}(2) - \hat{t}(1)}{\hat{t}(3) - \hat{t}(1)}\\
    \\
    UpperRatio = \frac{\hat{t}(3) - \hat{t}(2)}{\hat{t}(3) - \hat{t}(1)}
    \end{align}
    $$
    '''
    # Check for the correct data type
    if not isinstance(data_frame, pd.DataFrame):
        print 'Wrong data type, dataframe expected'
    else:
        #Create Data frames for the upper and lower ratios:
        df_ur = np.ones(len(data_frame))
        df_lr = np.ones(len(data_frame))
        #Store each triplet in a temporary array:
        for i in range(0,len(data_frame)):
            temp_array = np.ones(3)
            for k in range(0,3):
                temp_array[k] = data_frame.iloc[i,(startIndex+k)]
            temp_array = np.sort(temp_array)
            #Calculate the upper and lower ratios from the sorted temporary array 
            #and store them in the respective DataFrames 
            df_lr[i] = (temp_array[1]-temp_array[0])/(temp_array[2]-temp_array[0])
            df_ur[i] = (temp_array[2]-temp_array[1])/(temp_array[2]-temp_array[0])
            if (df_lr[i]) == 0 and (df_ur[i]) != 1:
                print "data issues, the distances are not complementary"
        #Drop NaN values
        df_ur = df_ur[~np.isnan(df_ur)] 
        df_lr = df_lr[~np.isnan(df_lr)] 
        #Make sure the dimensions are correct
        df_ur= np.squeeze(df_ur)  
        df_lr= np.squeeze(df_lr) 
    return df_lr, df_ur

# %%
merged_colony_data_d = DistanceRatioCalculation(merged_colony_data)
print 'Total number of colony data triplets (VR) ' + str(len(merged_colony_data_d[0]))
bishayee_colony2_d = DistanceRatioCalculation(bishayee_colony2)
print 'Total number of suspected colony data triplets (VR) ' + str(len(bishayee_colony2_d[0]))
others_colony2_d = DistanceRatioCalculation(others_colony2)
print 'Total number of others colony data triplets (VR) ' + str(len(others_colony2_d[0]))
outside3_colony2_d = DistanceRatioCalculation(outside3_colony2)
print 'Total number of outside lab 3 colony data triplets (VR) ' + str(len(outside3_colony2_d[0]))
# Out:
# Total number of colony data triplets (VR) 2005
# Total number of suspected colony data triplets (VR) 1360
# Total number of others colony data triplets (VR) 595
# Total number of outside lab 3 colony data triplets (VR) 50

# %%
merged_coulter_data_d = DistanceRatioCalculation(merged_coulter_data)
print 'Total number of Coulter data triplets (VR) ' + str(len(merged_coulter_data_d[0]))
bishayee_coulter2_d = DistanceRatioCalculation(bishayee_coulter2)
print 'Total number of suspected Coulter data triplets (VR) ' + str(len(bishayee_coulter2_d[0]))
others_coulter2_d = DistanceRatioCalculation(others_coulter2)
print 'Total number of others Coulter data triplets (VR) ' + str(len(others_coulter2_d[0]))
outside1_coulter2_d = DistanceRatioCalculation(outside1_coulter2)
print 'Total number of outside lab1 data triplets (VR) ' + str(len(outside1_coulter2_d[0]))
outside2_coulter2_d = DistanceRatioCalculation(outside2_coulter2)
print 'Total number of outside lab2 data triplets (VR) ' + str(len(outside2_coulter2_d[0]))
# Out:
# Total number of Coulter data triplets (VR) 2873
# Total number of suspected Coulter data triplets (VR) 1727
# Total number of others Coulter data triplets (VR) 929
# Total number of outside lab1 data triplets (VR) 97
# Total number of outside lab2 data triplets (VR) 120

# %% [markdown]
# ## Final analysis of the data count
#
# The final counts of the valid ratios to be statistically analyzed are sufficiently similar to the reported values in Table 2, thus, we are confindent in using the data in the forthcoming tests.

# %% [markdown]
# # Testing of the uniformity assumption about the benchmark data
#
# The authors made several assumptions about the underlying structure of the data and perform a set of tests. To confirm the validity of some of these assumptions, we propose a complementary set of tests. The tests carried out are as follows:
#
# * Create a synthetic set of data from a Poisson random variable for each row to test uniformity of the distance ratios.
#
# * Perform a [Kolmogorov-Smirnov test](https://en.wikipedia.org/wiki/Kolmogorov–Smirnov_test) test of the data comparing with a uniform distribution, both for the grouped benchmark data, individally for each dataset and for the suspected data.
#
# After calculating the different ratios, it is possible to make a visual inspection of the data as in Figures 1(a) and 2(b) in the paper.

# %% [markdown]
# ### Test of Poisson generated data
#
# To test uniformity of the ratios we first create dataframes with three columns where each column was obtained as three independent samples from a Poisson with equal mean. That mean is the average of the row for a given dataset, e.g. the colony data for the RTS person.

# %%
def CreatePoissonDataFrame(data):
    '''
    Input: data: Dataframe which we assume it has a column average
    The method returns a dataframe with  three columns ('col1', 'col2',
    'col3') where each element was obtained from independent Poisson random
    variable with mean equal to the original entry in the 'average'  column
    in the starting	dataframe.
    '''
    columnSize=data.shape[0]
    col1=np.zeros(columnSize)
    col2=np.zeros(columnSize)
    col3=np.zeros(columnSize)    
    for i in range(0,columnSize):
        #Generating poisiion data using the mean provided in the dataset
        aux = np.random.poisson(data.iloc[i]['average'], 3)
        col1[i]=aux[0]
        col2[i]=aux[1]
        col3[i]=aux[2]
    dataToReturn = pd.DataFrame(
    {'col1': col1,     'col2': col2,
     'col3': col3}, columns=['col1','col2','col3'])
    return dataToReturn

# %% [markdown]
# Dataframes are create for the Poisson below for all sources of cooulter/colony count data. Later, the columns are renamed as necessary to enable the processing.

# %%
#Renaming the columns for use with the CreatePoission function
merged_coulter_data=merged_coulter_data.rename(columns={'Average':'average'})
others_coulter2=others_coulter2.rename(columns={'Average':'average'})
outside1_coulter2=outside1_coulter2.rename(columns={'Average':'average'})
outside2_coulter2=outside2_coulter2.rename(columns={'Average':'average'})

# Creating Poisson data for each of the data sets provided
mer3_col=CreatePoissonDataFrame(merged_colony_data)
mer3_col2=CreatePoissonDataFrame(bishayee_colony2)
mer3_ocol=CreatePoissonDataFrame(others_colony2)
mer3_oucol=CreatePoissonDataFrame(outside3_colony2)
mer3_coul=CreatePoissonDataFrame(merged_coulter_data)
mer3_ocoul=CreatePoissonDataFrame(others_coulter2)
mer3_oucoul=CreatePoissonDataFrame(outside1_coulter2)
mer3_oucoul2=CreatePoissonDataFrame(outside2_coulter2)

# %%
#Calculate the Ratios for the true Poisson Data
mer3_col_ratio=DistanceRatioCalculation(mer3_col,0)
mer3_col2_ratio=DistanceRatioCalculation(mer3_col2,0)
mer3_ocol_ratio=DistanceRatioCalculation(mer3_ocol,0)
mer3_oucol_ratio=DistanceRatioCalculation(mer3_oucol,0)
mer3_coul_ratio=DistanceRatioCalculation(mer3_coul,0)
mer3_ocoul_ratio=DistanceRatioCalculation(mer3_ocoul,0)
mer3_oucoul_ratio=DistanceRatioCalculation(mer3_oucoul,0)
mer3_oucoul2_ratio=DistanceRatioCalculation(mer3_oucoul2,0)

# %% [markdown]
# After generating the data, uniformity tests are carried out as follows.

# %%
def VisualInspectionAgainstUnif(array_Data,label):
    """
    This function takes a data array as an input and plots the CDF of the data array vs. the uniform CDF
    """
    sample_uniform = np.random.uniform(0,1,1000)
    plt.title(label)
    cdf_plot(array_Data)
    cdf_plot(sample_uniform)

# %% [markdown]
# Along with visual inspection of the distribution of the ratios, we calculate the [Kolmogorov-Smirnov test](https://en.wikipedia.org/wiki/Kolmogorov–Smirnov_test) statistic with respect to the uniform distribution. Keeping in mind that the power of the test statistic is dependent on the sample size, and the benchmark data set are significantly smaller than the suspected RTS data, as acknowledged by the authors. The visual inspection of the data sets is as follows:

# %% [markdown]
# #### Visual Inspection of Lower Ratios

# %%
#PLotting all the CDFs for the possion data to compare against the uniform CDF
plt.figure()
plt.subplots(figsize=(20,20))
plt.subplot(421, aspect = 1.0)
VisualInspectionAgainstUnif(mer3_col_ratio[0], "Colony Lower Ratio")
plt.subplot(422, aspect = 1.0)
VisualInspectionAgainstUnif(mer3_col2_ratio[0], "Bishayee Colony Lower Ratio")
plt.subplot(423, aspect = 1.0)
VisualInspectionAgainstUnif(mer3_ocol_ratio[0], "Others Colony Lower Ratio")
plt.subplot(424, aspect = 1.0)
VisualInspectionAgainstUnif(mer3_oucol_ratio[0], "Outside Colony Lower Ratio")
plt.subplot(425, aspect = 1.0)
VisualInspectionAgainstUnif(mer3_coul_ratio[0], "Coulter Lower Ratio")
plt.subplot(426, aspect = 1.0)
VisualInspectionAgainstUnif(mer3_ocoul_ratio[0], "Others Coulter Lower Ratio")
plt.subplot(427, aspect = 1.0)
VisualInspectionAgainstUnif(mer3_oucoul_ratio[0], "Outside 1 Coulter Lower Ratio")
plt.subplot(428, aspect = 1.0)
VisualInspectionAgainstUnif(mer3_oucoul2_ratio[0], "Outside 2 Coulter Lower Ratio")
plt.tight_layout()

# %% [markdown]
# #### Visual Inspection of Upper Ratios

# %%
#Plotting all the CDFs for the possion data to compare against the uniform CDF
plt.figure()
plt.subplots(figsize=(20,20))
#plt.subplot(521, aspect = 1.0)
#VisualInspectionAgainstUnif(mer3_col_ratio[0], "Colony Upper Ratio")
plt.subplot(421, aspect = 1.0)
VisualInspectionAgainstUnif(mer3_col_ratio[1]," Colony Population Upper Ratio")
plt.subplot(422, aspect = 1.0)
VisualInspectionAgainstUnif(mer3_col2_ratio[1],"Bishayee Colony Upper Ratio")
plt.subplot(423, aspect = 1.0)
VisualInspectionAgainstUnif(mer3_ocol_ratio[1]," Others Colony Upper Ratio")
plt.subplot(424, aspect = 1.0)
VisualInspectionAgainstUnif(mer3_oucol_ratio[1],"Outside Colony Upper Ratio")
plt.subplot(425, aspect = 1.0)
VisualInspectionAgainstUnif(mer3_coul_ratio[1], "Coulter Population Upper Ratio")
plt.subplot(426, aspect = 1.0)
VisualInspectionAgainstUnif(mer3_ocoul_ratio[1], "Others Coulter Upper Ratio")
plt.subplot(427, aspect = 1.0)
VisualInspectionAgainstUnif(mer3_oucoul_ratio[1], "Outside 1 Coulter Upper Ratio")
plt.subplot(428, aspect = 1.0)
VisualInspectionAgainstUnif(mer3_oucoul2_ratio[1],"Outside 2 Colony Upper Ratio")
plt.tight_layout()

# %%
print 'Results for the Lower Ratio'
print 'KS value for the total colony population ' + str(stats.kstest(mer3_col_ratio[0], 'uniform')[0])
print 'KS value for the suspected colony data ' + str(stats.kstest(mer3_col2_ratio[0], 'uniform')[0])
print 'KS value for others colony data ' + str(stats.kstest(mer3_ocol_ratio[0], 'uniform')[0])
print 'KS value for outside3 colony data ' + str(stats.kstest(mer3_oucol_ratio[0], 'uniform')[0])
print 'KS value for total Coulter population data ' + str(stats.kstest(mer3_coul_ratio[0], 'uniform')[0])
print 'KS value for others Coulter data ' + str(stats.kstest(mer3_ocoul_ratio[0], 'uniform')[0])
print 'KS value for outside1 Coulter data ' + str(stats.kstest(mer3_oucoul_ratio[0], 'uniform')[0])
print 'KS value for outside2 Coulter data ' + str(stats.kstest(mer3_oucoul2_ratio[0], 'uniform')[0])
# Out:
# Results for the Lower Ratio
# KS value for the total colony population 0.0564153769346
# KS value for the suspected colony data 0.0567428150332
# KS value for others colony data 0.070351758794
# KS value for outside3 colony data 0.0847058823529
# KS value for total Coulter population data 0.025069637883
# KS value for others Coulter data 0.0457042390459
# KS value for outside1 Coulter data 0.12915933283
# KS value for outside2 Coulter data 0.104487179487

# %%
print 'Results for the Upper Ratio'
print 'KS value for the total colony population ' + str(stats.kstest(mer3_col_ratio[1], 'uniform')[0])
print 'KS value for the suspected colony data ' + str(stats.kstest(mer3_col2_ratio[1], 'uniform')[0])
print 'KS value for others colony data ' + str(stats.kstest(mer3_ocol_ratio[1], 'uniform')[0])
print 'KS value for outside3 colony data ' + str(stats.kstest(mer3_oucol_ratio[1], 'uniform')[0])
print 'KS value for total Coulter population data ' + str(stats.kstest(mer3_coul_ratio[1], 'uniform')[0])
print 'KS value for others Coulter data ' + str(stats.kstest(mer3_ocoul_ratio[1], 'uniform')[0])
print 'KS value for outside1 Coulter data ' + str(stats.kstest(mer3_oucoul_ratio[1], 'uniform')[0])
print 'KS value for outside2 Coulter data ' + str(stats.kstest(mer3_oucoul2_ratio[1], 'uniform')[0])
# Out:
# Results for the Upper Ratio
# KS value for the total colony population 0.0564153769346
# KS value for the suspected colony data 0.0567428150332
# KS value for others colony data 0.070351758794
# KS value for outside3 colony data 0.0847058823529
# KS value for total Coulter population data 0.025069637883
# KS value for others Coulter data 0.0457042390459
# KS value for outside1 Coulter data 0.12915933283
# KS value for outside2 Coulter data 0.104487179487

# %% [markdown]
# For larger sample sizes, both the visual inspection and the KS test show that the assumption of uniformity on the ratios is reasonable for data generated from Poisson random variables. In this test, we have made the calculation with the sample sizes as the original data, and the results show that the quality of the test is affected by the number of samples.
#
# It is noteworthy that some of the samples generated from the poission distribution have a mid ratio distribution that is significantly different from the uniform CDF as seen from the plots. Hence looking at the suspected data in isolation and comparing it to the aggregated data from all the other sources may not be the best approach, since the individual components of the aggregate benchmark set may have significant deviations from a uniform distribution.

# %% [markdown]
# ### Test of the data provided in the paper

# %%
def uniformkspermutation(data,permutations,sample_size = 100):
    """
    This function is designed to take a set of data and perform a KS statistic permutation test 
    against an uniform distribution sample of size 10000. The output is an array of size 
    trials of KS statistics. 
    
    inputs: data is the total population of data
    permutations: is the number of permutations 
    sample_size: is the sample size of the data draw for each permutation
    """    
    #Create the result array of appropriate size
    result_array = np.ones(permutations)
    
    for t in range(0,permutations):
        #Call the function ReturnSample to sample the population 
        permutationsample = ReturnSample(data,sample_size)
        #Perform the kstest to calculate the difference of the CDF of the sample from the uniform 
        #distribtuion
        test_result =stats.kstest(permutationsample, 'uniform')
        #Discard the p-value and store the KS statistic obtained from stats.kstest 
        #into the result array
        result_array[t] = test_result[0]
    return np.squeeze(result_array)

# %% [markdown]
# Given the results of the test carried out to validate the assumption of uniformity on the distance ratios test for data generated using the model described in the paper, i.e., each triplet is three independent realizations of a Poisson random variable.

# %% [markdown]
# #### Figure 1(b) check.
# The authors presented a histogram to validate the assumption of uniformity of lumped benchmark data, here we propose to perform a KS test to validate that assumption. First, we present a visual inspection of the CDFs against the uniform, and the KS statistic.

# %%
# Potting the CDF of the data from the other researchers vs the Uniform CDF
sample_uniform = np.random.uniform(0,1,10000)
cdf_plot(np.concatenate((others_colony2_d[0],outside3_colony2_d[0])))
cdf_plot(np.concatenate((others_colony2_d[1],outside3_colony2_d[1])))
cdf_plot(sample_uniform)

# %%
def ReturnSample(data,n):
    """ This function takes in an array/list and returns from it a random sample 
    of specified size without replacement.
    Inputs:
    data: The array/list to be sampled
    n: size of the smaple
    
    Return:
    Array with n elements from the data
    """
    indexes=rnd.sample(range(1,len(data)),n)  
    return np.asarray([data[i] for i in indexes])

# %% [markdown]
# ### KS test
#
# To check the level of the [Kolmogorov-Smirnov test](https://en.wikipedia.org/wiki/Kolmogorov–Smirnov_test), we use the stats package of scipy which has an implementation of the KS test.

# %%
# Creating the benchmark data from the other researchers and outside lab data
benchmark_sample = np.concatenate((others_colony2_d[0],outside3_colony2_d[0]));
print 'The KS statistic results LR are ' + str(stats.kstest(benchmark_sample, 'uniform'))
benchmark_sample = np.concatenate((others_colony2_d[1],outside3_colony2_d[1]));
print 'The KS statistic results UR are ' + str(stats.kstest(benchmark_sample, 'uniform'))
# Out:
# The KS statistic results LR are (0.083720930232558138, 0.00022137546051403945)
# The KS statistic results UR are (0.083720930232558111, 0.00022137546051403945)

# %% [markdown]
# The resulting p-values for the benchmark data call for some discussion regarding the significance of the test. On one hand, provided that the test was not carried out over a random sample of a large population, the power of the result can be questioned. However, it is a good indicator that the assumption of uniformity is not that surprising for the given data.

# %% [markdown]
# ### Figure 1(a) check.
#
# The same analysis as before is carried out, but using the suspicious data

# %%
sample_uniform = np.random.uniform(0,1,10000)
cdf_plot(bishayee_colony2_d[0])
cdf_plot(bishayee_colony2_d[1])
cdf_plot(sample_uniform)

# %%
# Creating the benchmark data from the other researchers and outside lab data
print 'The KS statistic results LR are ' + str(stats.kstest(bishayee_colony2_d[0], 'uniform'))
print 'The KS statistic results UR are ' + str(stats.kstest(bishayee_colony2_d[1], 'uniform'))
# Out:
# The KS statistic results LR are (0.22573529411764703, 0.0)
# The KS statistic results UR are (0.22573529411764709, 0.0)

# %% [markdown]
# As can be seen from the results of the two tests, the difference between the suspected data and the benchmark data's KS statistic is quite large. However this could have occured by chance. To check whether this difference is anomalous we perform permutation tests in the following section.

# %% [markdown]
# ### [Kolmogorov-Smirnov](https://en.wikipedia.org/wiki/Kolmogorov–Smirnov_test) permutation test
#
# Since the data is not a random sample from a bigger population, the p-values from the analysis performed in the previous section are unlikely to be meaningful, for this reason we decided re-analyze the data with a permutation test.
#
# Considering that the authors decided to test against the uniform distribution, we performed a permutation test for the KS statistic. In this test, we analyze whether the difference in the distribution of the ratio from the suspected data to the uniform distribution is "surprising." The reason we perform this test is because deviation from the uniform distribution appears to be used as a justification for finding the RTS suspicious.

# %%
def kstestpermutation(susData,allData,permutations):
    """
    This function first calculates the difference between the suspected person's ratio distribution and 
    the uniform distribution's cumulative density function using the Kolmogorov-Smirnov test.

    Then we lump together all the data of the suspected person, other people in his lab and the outside 
    scientists. From this larger population we draw a sample of the same size as that of the suspected 
    person's data. We then calcualte the difference between the randomly drawn sample and the unform 
    distribution via the KS test.     
    
    The result of the KS test for each permutation is stored in an array. 
    The frequency distribution of the KS statistic is then plotted and we then find the probability that 
    the difference that we observed could have been observed by chance.
    
    The return of the p-value corresponds to upper value between the estimated p-value and the inverse
    of the number of permutations
    
    """
    
    #Step 1. Difference from suspected data
    orig_Diff=stats.kstest(susData, 'uniform')
    #Step 2. Permute overall population and blabla
    real_Diff=uniformkspermutation(allData,permutations,len(susData))
    #Step 3. Plot the differences.
    test1_plot= plt.figure()
    plt.hist(real_Diff, bins = 100)
    plt.axvline(x=orig_Diff[0], color = 'r')
    #Step 4. Obtain the p-vlue from the data.
    aux_array=real_Diff[np.where(real_Diff<orig_Diff[0])]
    val_less_than_orig=len(aux_array)
    aux=(val_less_than_orig*1.0)/(len(real_Diff)*1.0)
    result = max((1-aux), 1/permutations)
    return "{:.2e}".format(result)

# %%
#Lower Ratio analysis. 
print 'p-value Colony LR ' + str(kstestpermutation(bishayee_colony2_d[0],merged_colony_data_d[0],10000))
#Upper Ratio analysis 
print 'p-value Colony UR ' + str(kstestpermutation(bishayee_colony2_d[1],merged_colony_data_d[1],10000))
#Fix the return value of the p-value
# Out:
# p-value Colony LR 1.00e-04
# p-value Colony UR 1.00e-04

# %%
#lower coulter ration
print 'p-value Coulter LR ' + str(kstestpermutation(bishayee_coulter2_d[0],merged_coulter_data_d[0],10000))
#Upper coulter ratio
print 'p-value Coulter UR ' + str(kstestpermutation(bishayee_coulter2_d[1],merged_coulter_data_d[1],10000))
# Out:
# p-value Coulter LR 1.00e-04
# p-value Coulter UR 1.00e-04

# %% [markdown]
# ### Results Discussion
#
# The results show that both the UR and LR value of the KS distance from the uniform distribution are indeed surprising, this is a result that confirms the hypothesis in the paper. The interesting result is that the distance ratios for the suspected data are abnormal even though they represent a large portion of the population.
#
# Most surprising is the fact that no other permutation of the data produced such a large difference from the uniform distribution in 10,000 trials.

# %% [markdown]
# ## Two sample KS test.
#
# The results so far show that the uniformity assumption is reasonable, and the test presented in the previous section show that it is possible to draw statistical conclusions about the distance ratios when compared with a uniform distribution.
#
# In our opinion, a more direct test of the difference between the suspected data and the benchmark data would be a 2-sample test of the distributions, instead of measuring their deviation from the uniform distribution or any other pre-established distribution.
#
# The results are as follows:

# %%
benchmark_sample_colony = np.concatenate((others_colony2_d[0],outside3_colony2_d[0]));
benchmark_sample_coulter = np.concatenate((others_coulter2_d[0],outside1_coulter2_d[0],outside2_coulter2_d[0]));

# %%
def ReturnSampleAndComplement(data,n):
    """
    This function takes in an array/list and splits it into two samples one of 
    size n and one of size (len(data) - n).

    Inputs:
    data: The array/list to be sampled
    n: size of the sample
    
    Return:
    Array with n elements chosen from the data, Array with the elements of the complement 
    of the first array
    """
    indexes=rnd.sample(range(1,len(data)),n)  
    return (np.asarray([data[i] for i in indexes]),np.asarray([data[i] for i in range(1,n) if i not in indexes]))

# %%
def ks2samplepermutation(data_suspected, data_all, trials):
    """
    This function is designed to take a set of the data "data_benchmark" and perform a KS statistic permutation test 
    against a larger sample to determine whether "data_benchmark" could have been produced from data with the same
    statistical nature as the "data_test"
    """
    result_array = np.ones(trials)
    for t in range(0,trials):
        #Split the overall data into 2 random subsets of fixed sizes
        permutationsample = ReturnSampleAndComplement(data_all,len(data_suspected))
        sample_1 = permutationsample[0]
        sample_2 = permutationsample[1]
        #Perform the 2 sample KS test for the random subsets and store the results in an array
        result = stats.ks_2samp(sample_1, sample_2)
        result_array[t] = result[0]
    return np.squeeze(result_array)

# %%
def ks2stestpermutation(susData,otherData,allData,permutations):
    """
    This function performs the a perumtation test with the 2-sample KS statistic.
    Firstly the difference between the orignal data from the suspected data set and the other data set is caluclated and stored. 
    
    Then in order to build a distribution of the 2-sample KS statistic for this dataset, random samples with the same size as 
    suspected data and other data are drawn from the overall population. The KS statistic is then cajluclated for each 
    permutation and the results are stored in an array.
    
    Finally the KS statistic distribution is plotted and compared to the originial value of the KS statistic for the 
    suspected person's data. A p-value is obtained based on the number of permutations that have a KS-statistic that exceeds
    the original KS statistic.
    """
    #Step 1. Difference from suspected data
    orig_Diff=stats.ks_2samp(susData,otherData)
    #Step 2. Permute overall population and blabla
    real_Diff= ks2samplepermutation(susData,allData, permutations)
    #Step 3. Plot the differences.
    test1_plot= plt.figure()
    plt.hist(real_Diff, bins = 100)
    plt.axvline(x=orig_Diff[0], color = 'r')
    #Step 4. Be surprised "obtain p-value".
    aux_array=real_Diff[np.where(real_Diff<orig_Diff[0])]
    val_less_than_orig=len(aux_array)
    aux=(val_less_than_orig*1.0)/(len(real_Diff)*1.0)
    result = max((1-aux), 1/permutations)
    return "{:.2e}".format(result)

# %%
#Lower Ratio analysis
print 'p-value colony LR ' + str(ks2stestpermutation(bishayee_colony2_d[0],benchmark_sample_colony,merged_colony_data_d[0],1000))
#Upper ratio analysis
print 'p-value colony UR ' + str(ks2stestpermutation(bishayee_colony2_d[1],benchmark_sample_colony,merged_colony_data_d[1],1000))
# Out:
# p-value colony LR 1.00e-03
# p-value colony UR 1.00e-03

# %%
#Lower Ratio analysis
print 'p-value Coulter LR ' + str(ks2stestpermutation(bishayee_coulter2_d[0],benchmark_sample_coulter,merged_coulter_data_d[0],1000))
#Upper ratio analysis
print 'p-value Coulter UR ' + str(ks2stestpermutation(bishayee_coulter2_d[1],benchmark_sample_coulter,merged_coulter_data_d[1],1000))
# Out:
# p-value Coulter LR 3.00e-02
# p-value Coulter UR 1.17e-01

# %% [markdown]
# # Final Remarks
# The [paper](https://www.scienceopen.com/document/review?3&id=7a235c56-a1da-498f-98ef-6fa16c8fd2f0&review=9870bf08-c06e-403a-85ba-774e27cdb520) gives a good contribution for testing data from radiobiological experiments triplets, by proposing a model based on Poisson random variables as a metric based on distance ratios. Our tests show that the distance ratios obtained from samples using Poisson random variables converge to a uniform distribution. Moreover, it provides a good benchmark distribution by proposing testing distance ratio with the uniform for large sample sizes. As our results confirm that their new measure leads to a reasonable test for data of the kind studied in the paper. However, we are concerned about how the authors decided to test mid-ratios. If it was a post hoc analysis based on earlier visual inspection of the data, the results might suffer from "significance hunting," and it is hard to interpret the p-values.
#
# Finally, we propose an alternative test using the same metric of distance ratios but that it does not depend on any underlying distribution. The results from this test confirm the hypothesis the colony data from RTS does not share the same CDF as the benchmark data, the power of this test could be enhanced with betters samples.
