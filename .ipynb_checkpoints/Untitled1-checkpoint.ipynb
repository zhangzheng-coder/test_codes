# %%
# Import
from pyomo.environ import *
import pandas as pd
import pprint as pp

# Components:
#   SETS_ALL_CAPS
#   VarsCamelCase
#   params_lower_case_with_underscores
#   Constraints_Words_Capitalized_With_Underscores
# SET_time_system

# %%
model = ConcreteModel()
#Control of the model. 
time_steps = 4
Gamma = 6
Time_idx = [1,2,3,4]
Vert_idx = ['v{0}'.format(v+1) for v in range(int(2**time_steps))]

#SETS
model.time = Set(initialize=Time_idx, ordered = True)
model.VERTEX = Set(initialize=Vert_idx)
model.TV = Set(initialize=model.time*model.VERTEX)

#Parameters
prices = {1: 30,
          2: 35,
          3: 40,
          4: 33
          }
model.day_ahead_price = Param(model.time, initialize=prices)

wind = {1: 54,
        2: 65,
        3: 70,
        4: 33
          }
model.Wind_Generation = Param(model.time, initialize=wind)

lambda_d_list=[30,35,40,33]
lambda_d = {Time_idx[t]:lambda_d_list[t] for t in range(time_steps)}

psi_up = [5,12,8,15]
psi_dw = [-20,-5,-25,-10]

df=pd.DataFrame({Time_idx[t]:([psi_up[t]]*int(8/2**t)+[psi_dw[t]]*int(8/2**t))*int(2**t) for t in range(time_steps)},index=Vert_idx)
lambda_b={}
for t in Time_idx:
    for v in Vert_idx:
        lambda_b[t,v] = df.ix[v,t]+lambda_d[t]

model.pi = Param(model.TV, initialize=lambda_b)

model.SoC_ini = Param(initialize = 30)
model.SoC_end = Param(initialize = 30)
model.Gamma = Param(initialize = Gamma)

# variables
model.EnergyDayAhead = Var(model.time, within=NonNegativeReals, bounds=(0,120))
model.EnergyBalancing = Var(model.time)
model.Beta = Var()
model.Zeta = Var(model.VERTEX, within=NonNegativeReals, bounds=(0,0))
model.EnergyStorage = Var(model.time)
model.PinStorage = Var(model.time, within=NonNegativeReals, bounds=(0,20))
model.PoutStorage = Var(model.time, within=NonNegativeReals, bounds=(0,20))
model.SoCStorage = Var(model.time, within=NonNegativeReals, bounds=(0,60))

#Objective Function 
def cost_rule(mdl):
    DayAheadCost = sum(mdl.day_ahead_price[t]*mdl.EnergyDayAhead[t] for t in mdl.time)
    return  DayAheadCost + mdl.Beta
model.costTotal = Objective(rule=cost_rule, sense=maximize)

#Constraints 
def cuts(mdl,v):
    return mdl.Beta <= sum (mdl.pi[t,v]*mdl.EnergyBalancing[t] for t in mdl.time) + mdl.Zeta[v]
model.Cuts = Constraint(model.VERTEX, rule=cuts)

def budget_uncertainty_def(mdl,v,t,tp):
    return mdl.Zeta[v] <= mdl.Gamma*mdl.pi[tp,v]*mdl.EnergyBalancing[t]
#model.budget_uncertainty= Constraint(model.VERTEX, model.time, model.time, rule = budget_uncertainty_def)    

def balance(mdl,t):
    return mdl.EnergyDayAhead[t] + mdl.EnergyBalancing[t] == mdl.Wind_Generation[t] + mdl.EnergyStorage[t]
model.balance = Constraint(model.time, rule=balance) 

def storage_power(mdl,t):
    return mdl.EnergyStorage[t] == mdl.PoutStorage[t] - mdl.PinStorage[t]
model.storage_power = Constraint(model.time, rule=storage_power) 

def storage_energy(mdl,t):
    idx = 'a'
    if t == 1:
        return mdl.SoCStorage[t] == mdl.SoC_ini - mdl.PoutStorage[t]*(1/0.9) + 0.9*mdl.PinStorage[t]
    elif t  > 1:
        return mdl.SoCStorage[t] == mdl.SoCStorage[t-1] - mdl.PoutStorage[t]*(1/0.9) + 0.9*mdl.PinStorage[t]
model.storage_energy = Constraint(model.time, rule=storage_energy)
model.final_condition = Constraint(expr = model.SoCStorage[4] ==  model.SoC_end)

model.pprint()
# Out:
# 4 Set Declarations
#     TV : Dim=0, Dimen=2, Size=64, Domain=None, Ordered=False, Bounds=None
#         [(1, 'v1'), (1, 'v10'), (1, 'v11'), (1, 'v12'), (1, 'v13'), (1, 'v14'), (1, 'v15'), (1, 'v16'), (1, 'v2'), (1, 'v3'), (1, 'v4'), (1, 'v5'), (1, 'v6'), (1, 'v7'), (1, 'v8'), (1, 'v9'), (2, 'v1'), (2, 'v10'), (2, 'v11'), (2, 'v12'), (2, 'v13'), (2, 'v14'), (2, 'v15'), (2, 'v16'), (2, 'v2'), (2, 'v3'), (2, 'v4'), (2, 'v5'), (2, 'v6'), (2, 'v7'), (2, 'v8'), (2, 'v9'), (3, 'v1'), (3, 'v10'), (3, 'v11'), (3, 'v12'), (3, 'v13'), (3, 'v14'), (3, 'v15'), (3, 'v16'), (3, 'v2'), (3, 'v3'), (3, 'v4'), (3, 'v5'), (3, 'v6'), (3, 'v7'), (3, 'v8'), (3, 'v9'), (4, 'v1'), (4, 'v10'), (4, 'v11'), (4, 'v12'), (4, 'v13'), (4, 'v14'), (4, 'v15'), (4, 'v16'), (4, 'v2'), (4, 'v3'), (4, 'v4'), (4, 'v5'), (4, 'v6'), (4, 'v7'), (4, 'v8'), (4, 'v9')]
#     TV_index_init : Dim=0, Dimen=2, Size=64, Domain=None, Ordered=False, Bounds=None
#         Virtual
#     VERTEX : Dim=0, Dimen=1, Size=16, Domain=None, Ordered=False, Bounds=None
#         ['v1', 'v10', 'v11', 'v12', 'v13', 'v14', 'v15', 'v16', 'v2', 'v3', 'v4', 'v5', 'v6', 'v7', 'v8', 'v9']
#     time : Dim=0, Dimen=1, Size=4, Domain=None, Ordered=Insertion, Bounds=(1, 4)
#         [1, 2, 3, 4]
#
# 6 Param Declarations
#     Gamma : Size=1, Index=None, Domain=Any, Default=None, Mutable=False
#         Key  : Value
#         None :     6
#     SoC_end : Size=1, Index=None, Domain=Any, Default=None, Mutable=False
#         Key  : Value
#         None :    30
#     SoC_ini : Size=1, Index=None, Domain=Any, Default=None, Mutable=False
#         Key  : Value
#         None :    30
#     Wind_Generation : Size=4, Index=time, Domain=Any, Default=None, Mutable=False
#         Key : Value
#           1 :    54
#           2 :    65
#           3 :    70
#           4 :    33
#     day_ahead_price : Size=4, Index=time, Domain=Any, Default=None, Mutable=False
#         Key : Value
#           1 :    30
#           2 :    35
#           3 :    40
#           4 :    33
#     pi : Size=64, Index=TV, Domain=Any, Default=None, Mutable=False
#         Key        : Value
#          (1, 'v1') :    35
#         (1, 'v10') :    10
#         (1, 'v11') :    10
#         (1, 'v12') :    10
#         (1, 'v13') :    10
#         (1, 'v14') :    10
#         (1, 'v15') :    10
#         (1, 'v16') :    10
#          (1, 'v2') :    35
#          (1, 'v3') :    35
#          (1, 'v4') :    35
#          (1, 'v5') :    35
#          (1, 'v6') :    35
#          (1, 'v7') :    35
#          (1, 'v8') :    35
#          (1, 'v9') :    10
#          (2, 'v1') :    47
#         (2, 'v10') :    47
#         (2, 'v11') :    47
#         (2, 'v12') :    47
#         (2, 'v13') :    30
#         (2, 'v14') :    30
#         (2, 'v15') :    30
#         (2, 'v16') :    30
#          (2, 'v2') :    47
#          (2, 'v3') :    47
#          (2, 'v4') :    47
#          (2, 'v5') :    30
#          (2, 'v6') :    30
#          (2, 'v7') :    30
#          (2, 'v8') :    30
#          (2, 'v9') :    47
#          (3, 'v1') :    48
#         (3, 'v10') :    48
#         (3, 'v11') :    15
#         (3, 'v12') :    15
#         (3, 'v13') :    48
#         (3, 'v14') :    48
#         (3, 'v15') :    15
#         (3, 'v16') :    15
#          (3, 'v2') :    48
#          (3, 'v3') :    15
#          (3, 'v4') :    15
#          (3, 'v5') :    48
#          (3, 'v6') :    48
#          (3, 'v7') :    15
#          (3, 'v8') :    15
#          (3, 'v9') :    48
#          (4, 'v1') :    48
#         (4, 'v10') :    23
#         (4, 'v11') :    48
#         (4, 'v12') :    23
#         (4, 'v13') :    48
#         (4, 'v14') :    23
#         (4, 'v15') :    48
#         (4, 'v16') :    23
#          (4, 'v2') :    23
#          (4, 'v3') :    48
#          (4, 'v4') :    23
#          (4, 'v5') :    48
#          (4, 'v6') :    23
#          (4, 'v7') :    48
#          (4, 'v8') :    23
#          (4, 'v9') :    48
#
# 8 Var Declarations
#     Beta : Size=1, Index=None, Domain=Reals
#         Key  : Lower : Value : Upper : Fixed : Stale
#         None :  None :  None :  None : False :  True
#     EnergyBalancing : Size=4, Index=time, Domain=Reals
#         Key : Lower : Value : Upper : Fixed : Stale
#           1 :  None :  None :  None : False :  True
#           2 :  None :  None :  None : False :  True
#           3 :  None :  None :  None : False :  True
#           4 :  None :  None :  None : False :  True
#     EnergyDayAhead : Size=4, Index=time, Domain=NonNegativeReals
#         Key : Lower : Value : Upper : Fixed : Stale
#           1 :     0 :  None :   120 : False :  True
#           2 :     0 :  None :   120 : False :  True
#           3 :     0 :  None :   120 : False :  True
#           4 :     0 :  None :   120 : False :  True
#     EnergyStorage : Size=4, Index=time, Domain=Reals
#         Key : Lower : Value : Upper : Fixed : Stale
#           1 :  None :  None :  None : False :  True
#           2 :  None :  None :  None : False :  True
#           3 :  None :  None :  None : False :  True
#           4 :  None :  None :  None : False :  True
#     PinStorage : Size=4, Index=time, Domain=NonNegativeReals
#         Key : Lower : Value : Upper : Fixed : Stale
#           1 :     0 :  None :    20 : False :  True
#           2 :     0 :  None :    20 : False :  True
#           3 :     0 :  None :    20 : False :  True
#           4 :     0 :  None :    20 : False :  True
#     PoutStorage : Size=4, Index=time, Domain=NonNegativeReals
#         Key : Lower : Value : Upper : Fixed : Stale
#           1 :     0 :  None :    20 : False :  True
#           2 :     0 :  None :    20 : False :  True
#           3 :     0 :  None :    20 : False :  True
#           4 :     0 :  None :    20 : False :  True
#     SoCStorage : Size=4, Index=time, Domain=NonNegativeReals
#         Key : Lower : Value : Upper : Fixed : Stale
#           1 :     0 :  None :    60 : False :  True
#           2 :     0 :  None :    60 : False :  True
#           3 :     0 :  None :    60 : False :  True
#           4 :     0 :  None :    60 : False :  True
#     Zeta : Size=16, Index=VERTEX, Domain=NonNegativeReals
#         Key : Lower : Value : Upper : Fixed : Stale
#          v1 :     0 :  None :     0 : False :  True
#         v10 :     0 :  None :     0 : False :  True
#         v11 :     0 :  None :     0 : False :  True
#         v12 :     0 :  None :     0 : False :  True
#         v13 :     0 :  None :     0 : False :  True
#         v14 :     0 :  None :     0 : False :  True
#         v15 :     0 :  None :     0 : False :  True
#         v16 :     0 :  None :     0 : False :  True
#          v2 :     0 :  None :     0 : False :  True
#          v3 :     0 :  None :     0 : False :  True
#          v4 :     0 :  None :     0 : False :  True
#          v5 :     0 :  None :     0 : False :  True
#          v6 :     0 :  None :     0 : False :  True
#          v7 :     0 :  None :     0 : False :  True
#          v8 :     0 :  None :     0 : False :  True
#          v9 :     0 :  None :     0 : False :  True
#
# 1 Objective Declarations
#     costTotal : Size=1, Index=None, Active=True
#         Key  : Active : Sense    : Expression
#         None :   True : maximize : 30*EnergyDayAhead[1] + 35*EnergyDayAhead[2] + 40*EnergyDayAhead[3] + 33*EnergyDayAhead[4] + Beta
#
# 5 Constraint Declarations
#     Cuts : Size=16, Index=VERTEX, Active=True
#         Key : Lower : Body                                                                                                             : Upper : Active
#          v1 :  -Inf :  Beta - 35*EnergyBalancing[1] - 47*EnergyBalancing[2] - 48*EnergyBalancing[3] - 48*EnergyBalancing[4] - Zeta[v1] :   0.0 :   True
#         v10 :  -Inf : Beta - 10*EnergyBalancing[1] - 47*EnergyBalancing[2] - 48*EnergyBalancing[3] - 23*EnergyBalancing[4] - Zeta[v10] :   0.0 :   True
#         v11 :  -Inf : Beta - 10*EnergyBalancing[1] - 47*EnergyBalancing[2] - 15*EnergyBalancing[3] - 48*EnergyBalancing[4] - Zeta[v11] :   0.0 :   True
#         v12 :  -Inf : Beta - 10*EnergyBalancing[1] - 47*EnergyBalancing[2] - 15*EnergyBalancing[3] - 23*EnergyBalancing[4] - Zeta[v12] :   0.0 :   True
#         v13 :  -Inf : Beta - 10*EnergyBalancing[1] - 30*EnergyBalancing[2] - 48*EnergyBalancing[3] - 48*EnergyBalancing[4] - Zeta[v13] :   0.0 :   True
#         v14 :  -Inf : Beta - 10*EnergyBalancing[1] - 30*EnergyBalancing[2] - 48*EnergyBalancing[3] - 23*EnergyBalancing[4] - Zeta[v14] :   0.0 :   True
#         v15 :  -Inf : Beta - 10*EnergyBalancing[1] - 30*EnergyBalancing[2] - 15*EnergyBalancing[3] - 48*EnergyBalancing[4] - Zeta[v15] :   0.0 :   True
#         v16 :  -Inf : Beta - 10*EnergyBalancing[1] - 30*EnergyBalancing[2] - 15*EnergyBalancing[3] - 23*EnergyBalancing[4] - Zeta[v16] :   0.0 :   True
#          v2 :  -Inf :  Beta - 35*EnergyBalancing[1] - 47*EnergyBalancing[2] - 48*EnergyBalancing[3] - 23*EnergyBalancing[4] - Zeta[v2] :   0.0 :   True
#          v3 :  -Inf :  Beta - 35*EnergyBalancing[1] - 47*EnergyBalancing[2] - 15*EnergyBalancing[3] - 48*EnergyBalancing[4] - Zeta[v3] :   0.0 :   True
#          v4 :  -Inf :  Beta - 35*EnergyBalancing[1] - 47*EnergyBalancing[2] - 15*EnergyBalancing[3] - 23*EnergyBalancing[4] - Zeta[v4] :   0.0 :   True
#          v5 :  -Inf :  Beta - 35*EnergyBalancing[1] - 30*EnergyBalancing[2] - 48*EnergyBalancing[3] - 48*EnergyBalancing[4] - Zeta[v5] :   0.0 :   True
#          v6 :  -Inf :  Beta - 35*EnergyBalancing[1] - 30*EnergyBalancing[2] - 48*EnergyBalancing[3] - 23*EnergyBalancing[4] - Zeta[v6] :   0.0 :   True
#          v7 :  -Inf :  Beta - 35*EnergyBalancing[1] - 30*EnergyBalancing[2] - 15*EnergyBalancing[3] - 48*EnergyBalancing[4] - Zeta[v7] :   0.0 :   True
#          v8 :  -Inf :  Beta - 35*EnergyBalancing[1] - 30*EnergyBalancing[2] - 15*EnergyBalancing[3] - 23*EnergyBalancing[4] - Zeta[v8] :   0.0 :   True
#          v9 :  -Inf :  Beta - 10*EnergyBalancing[1] - 47*EnergyBalancing[2] - 48*EnergyBalancing[3] - 48*EnergyBalancing[4] - Zeta[v9] :   0.0 :   True
#     balance : Size=4, Index=time, Active=True
#         Key : Lower : Body                                                            : Upper : Active
#           1 :   0.0 : -54 + EnergyDayAhead[1] + EnergyBalancing[1] - EnergyStorage[1] :   0.0 :   True
#           2 :   0.0 : -65 + EnergyDayAhead[2] + EnergyBalancing[2] - EnergyStorage[2] :   0.0 :   True
#           3 :   0.0 : -70 + EnergyDayAhead[3] + EnergyBalancing[3] - EnergyStorage[3] :   0.0 :   True
#           4 :   0.0 : -33 + EnergyDayAhead[4] + EnergyBalancing[4] - EnergyStorage[4] :   0.0 :   True
#     final_condition : Size=1, Index=None, Active=True
#         Key  : Lower   : Body          : Upper   : Active
#         None : SoC_end : SoCStorage[4] : SoC_end :   True
#     storage_energy : Size=4, Index=time, Active=True
#         Key : Lower : Body                                                                             : Upper : Active
#           1 :   0.0 :           -30 + SoCStorage[1] + 1.11111111111*PoutStorage[1] - 0.9*PinStorage[1] :   0.0 :   True
#           2 :   0.0 : SoCStorage[2] - SoCStorage[1] + 1.11111111111*PoutStorage[2] - 0.9*PinStorage[2] :   0.0 :   True
#           3 :   0.0 : SoCStorage[3] - SoCStorage[2] + 1.11111111111*PoutStorage[3] - 0.9*PinStorage[3] :   0.0 :   True
#           4 :   0.0 : SoCStorage[4] - SoCStorage[3] + 1.11111111111*PoutStorage[4] - 0.9*PinStorage[4] :   0.0 :   True
#     storage_power : Size=4, Index=time, Active=True
#         Key : Lower : Body                                              : Upper : Active
#           1 :   0.0 : EnergyStorage[1] - PoutStorage[1] + PinStorage[1] :   0.0 :   True
#           2 :   0.0 : EnergyStorage[2] - PoutStorage[2] + PinStorage[2] :   0.0 :   True
#           3 :   0.0 : EnergyStorage[3] - PoutStorage[3] + PinStorage[3] :   0.0 :   True
#           4 :   0.0 : EnergyStorage[4] - PoutStorage[4] + PinStorage[4] :   0.0 :   True
#
# 24 Declarations: time VERTEX TV_index_init TV day_ahead_price Wind_Generation pi SoC_ini SoC_end Gamma EnergyDayAhead EnergyBalancing Beta Zeta EnergyStorage PinStorage PoutStorage SoCStorage costTotal Cuts balance storage_power storage_energy final_condition

# %%
def pyomo_postprocess(options=None, instance=None, results=None):
    model.EnergyDayAhead.display()
    model.EnergyBalancing.display()
    model.EnergyStorage.display()
    model.SoCStorage.display()
    model.Beta.display()

# This is an optional code path that allows the script to be run outside of
# pyomo command-line.  For example:  python transport.py
if __name__ == '__main__':
    # This emulates what the pyomo command-line tools does
    from pyomo.opt import SolverFactory
    import pyomo.environ
    opt = SolverFactory("gurobi")
    results = opt.solve(model)
# sends results to stdout
    results.write()
    print("\nDisplaying Solution\n" + '-' * 60)
    pyomo_postprocess(None, None, results)
# Out:
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Name:
#   Lower bound: 7832.0
#   Upper bound: 7832.0
#   Number of objectives: 1
#   Number of constraints: 30
#   Number of variables: 42
#   Number of binary variables: 0
#   Number of integer variables: 0
#   Number of continuous variables: 42
#   Number of nonzeros: 137
#   Sense: maximize
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Return code: 0
#   Message: Model was solved to optimality (subject to tolerances), and an optimal solution is available.
#   User time: 0.0
#   System time: 0.0
#   Termination condition: optimal
#   Termination message: Model was solved to optimality (subject to tolerances), and an optimal solution is available.
#   Error rc: 0
#   Time: 0.767297029495
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
#
# Displaying Solution
# ------------------------------------------------------------
# EnergyDayAhead : Size=4, Index=time, Domain=NonNegativeReals
#     Key : Lower : Value : Upper : Fixed : Stale
#       1 :     0 :  34.0 :   120 : False : False
#       2 :     0 :  65.0 :   120 : False : False
#       3 :     0 :  86.2 :   120 : False : False
#       4 :     0 :  33.0 :   120 : False : False
# EnergyBalancing : Size=4, Index=time, Domain=Reals
#     Key : Lower : Value : Upper : Fixed : Stale
#       1 :  None :   0.0 :  None : False : False
#       2 :  None :   0.0 :  None : False : False
#       3 :  None :   0.0 :  None : False : False
#       4 :  None :   0.0 :  None : False : False
# EnergyStorage : Size=4, Index=time, Domain=Reals
#     Key : Lower : Value : Upper : Fixed : Stale
#       1 :  None : -20.0 :  None : False : False
#       2 :  None :   0.0 :  None : False : False
#       3 :  None :  16.2 :  None : False : False
#       4 :  None :   0.0 :  None : False : False
# SoCStorage : Size=4, Index=time, Domain=NonNegativeReals
#     Key : Lower : Value : Upper : Fixed : Stale
#       1 :     0 :  48.0 :    60 : False : False
#       2 :     0 :  48.0 :    60 : False : False
#       3 :     0 :  30.0 :    60 : False : False
#       4 :     0 :  30.0 :    60 : False : False
# Zeta : Size=16, Index=VERTEX, Domain=NonNegativeReals
#     Key : Lower : Value : Upper : Fixed : Stale
#      v1 :     0 :   0.0 :     0 : False : False
#     v10 :     0 :   0.0 :     0 : False : False
#     v11 :     0 :   0.0 :     0 : False : False
#     v12 :     0 :   0.0 :     0 : False : False
#     v13 :     0 :   0.0 :     0 : False : False
#     v14 :     0 :   0.0 :     0 : False : False
#     v15 :     0 :   0.0 :     0 : False : False
#     v16 :     0 :   0.0 :     0 : False : False
#      v2 :     0 :   0.0 :     0 : False : False
#      v3 :     0 :   0.0 :     0 : False : False
#      v4 :     0 :   0.0 :     0 : False : False
#      v5 :     0 :   0.0 :     0 : False : False
#      v6 :     0 :   0.0 :     0 : False : False
#      v7 :     0 :   0.0 :     0 : False : False
#      v8 :     0 :   0.0 :     0 : False : False
#      v9 :     0 :   0.0 :     0 : False : False
# Beta : Size=1, Index=None, Domain=Reals
#     Key  : Lower : Value : Upper : Fixed : Stale
#     None :  None :   0.0 :  None : False : False
